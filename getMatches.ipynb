# %%
from pyvisionproductsearch import ProductSearch, ProductCategories
from google.cloud import vision
from google.cloud.vision import types
import os
from dotenv import load_dotenv
import ipyplot
load_dotenv()
# Out:
# True

# %%
# ENV Variable
GCP_PROJECTID=""
BUCKET=""
LOCATION=""
CREDS=""
PRODUCT_SET=""
PRODUCT_SET_DISPLAY_NAME=""
IMAGE_BUCKET_PREFIX="product-images"

# %%
ps = ProductSearch(
    os.getenv("PROJECT_ID"),
    os.getenv("CREDS"),
    os.getenv("BUCKET"),
    os.getenv("LOCATION"),
    os.getenv("IMAGE-BUCKET-PREFIX")
)
productSet = ps.getProductSet(os.getenv("PRODUCT_SET"))

# %%
# TEST USING FILE URL
# TEST 1
test_image=[]
# test_image.append("https://i.pinimg.com/736x/f0/55/ef/f055ef33ca1540bc2d066b33190509b9.jpg")
# TEST 2
# test_image.append("https://i.pinimg.com/originals/cb/4a/8b/cb4a8bb6bc5a2da1f360c608dfc55301.jpg")
# TEST 3 
# test_image.append("https://th.bing.com/th/id/OIP.lgIHvd28XwlHm6ksrK-XZAHaFH?pid=ImgDet&rs=1")
# TEST 4
# test_image.append("https://th.bing.com/th/id/OIP.BCPvGp08AR45peT1QwvijQHaE7?pid=ImgDet&w=187&h=124&c=7")

test_image.append("https://64.media.tumblr.com/dd1b7283508dfc670029058820368a75/tumblr_ovtuzqa56U1w897cno1_1280.jpg")
# test_image.append("https://i.pinimg.com/736x/14/01/72/14017299d73a35fc425390f7f05a5dde.jpg")
products=productSet.search(ProductCategories.APPAREL, image_uri=test_image[0])

# %%
# TEST USING FILE PATH
test_image=[]
test_image.append("./test/test1.jpg")
products=productSet.search(ProductCategories.APPAREL, file_path=test_image[0])


test_image=[]
test_image.append("./test/test2.jpg")
products=productSet.search(ProductCategories.APPAREL, file_path=test_image[0])

test_image=[]
test_image.append("./test/test3.jpg")
products=productSet.search(ProductCategories.APPAREL, file_path=test_image[0])

# %%
images=[]
labels=[]
for product in products:
   pd=product['product']
   imgName =product['image'].split('/')[-1]
   name = product['image'].split('/')[-3]
   # The storage api makes these images publicly accessible through url
   imageUrl = f"https://storage.googleapis.com/{BUCKET}/{IMAGE_BUCKET_PREFIX}/" + imgName
   images.append(imageUrl)
   labels.append(name)

# %%
ipyplot.plot_images(test_image,["TEST IMAGE"], max_images=5, img_width=150)
ipyplot.plot_images(images,labels, max_images=5, img_width=150)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-e8w6o4RH7mUHrssqN987sk {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-e8w6o4RH7mUHrssqN987sk {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-e8w6o4RH7mUHrssqN987sk {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-e8w6o4RH7mUHrssqN987sk:checked ~ #ipyplot-html-viewer-textarea-e8w6o4RH7mUHrssqN987sk {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-e8w6o4RH7mUHrssqN987sk:checked + #ipyplot-html-viewer-label-e8w6o4RH7mUHrssqN987sk:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-e8w6o4RH7mUHrssqN987sk">
#         <label id="ipyplot-html-viewer-label-e8w6o4RH7mUHrssqN987sk" for="ipyplot-html-viewer-toggle-e8w6o4RH7mUHrssqN987sk">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea
/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-btq7fp52fzE226KSFUvRez-H4sr5Hi3m7F2R7zemdupQm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-btq7fp52fzE226KSFUvRez">
#         <div id="ipyplot-content-div-btq7fp52fzE226KSFUvRez-cnKKL8ySzBiQ3wP2CECBAF" class="ipyplot-content-div-btq7fp52fzE226KSFUvRez">
#             <h4 style="font-size: 12px; word-wrap: break-word;">OFXAIPRBL</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://storage.googleapis.com/image-bucket-cc/product-images/fcc7ed2b-4a8c-4858-8d11-eca2600324d4</h4><img src="https://storage.googleapis.com/image-bucket-cc/product-images/fcc7ed2b-4a8c-4858-8d11-eca2600324d4"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-btq7fp52fzE226KSFUvRez-cnKKL8ySzBiQ3wP2CECBAF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-btq7fp52fzE226KSFUvRez">
#         <div id="ipyplot-content-div-btq7fp52fzE226KSFUvRez-h8DDnpoHWUr95KHTnB4DMB" class="ipyplot-content-div-btq7fp52fzE226KSFUvRez">
#             <h4 style="font-size: 12px; word-wrap: break-word;">SAXBLLOWHPA</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://storage.googleapis.com/image-bucket-cc/product-images/e37d29d8-d6fd-45de-b180-6ac9111ea0d5</h4><img src="https://storage.googleapis.com/image-bucket-cc/product-images/e37d29d8-d6fd-45de-b180-6ac9111ea0d5"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-btq7fp52fzE226KSFUvRez-h8DDnpoHWUr95KHTnB4DMB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-btq7fp52fzE226KSFUvRez">
#         <div id="ipyplot-content-div-btq7fp52fzE226KSFUvRez-nXhmL8aa8BTn2P6AVzSBTc" class="ipyplot-content-div-btq7fp52fzE226KSFUvRez">
#             <h4 style="font-size: 12px; word-wrap: break-word;">AIMA90IN</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://storage.googleapis.com/image-bucket-cc/product-images/b24af22c-d90e-4d0f-8556-e3cf2f936265</h4><img src="https://storage.googleapis.com/image-bucket-cc/product-images/b24af22c-d90e-4d0f-8556-e3cf2f936265"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-btq7fp52fzE226KSFUvRez-nXhmL8aa8BTn2P6AVzSBTc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-btq7fp52fzE226KSFUvRez">
#         <div id="ipyplot-content-div-btq7fp52fzE226KSFUvRez-ZHTALQ48owomXbyVrX5htK" class="ipyplot-content-div-btq7fp52fzE226KSFUvRez">
#             <h4 style="font-size: 12px; word-wrap: break-word;">LOVUXNIAIFO1BYVIAB‘R</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://storage.googleapis.com/image-bucket-cc/product-images/710f28da-bf68-47bd-a3b5-43616470e7e7</h4><img src="https://storage.googleapis.com/image-bucket-cc/product-images/710f28da-bf68-47bd-a3b5-43616470e7e7"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#         <style>
#         #ipyplot-imgs-container-div-btq7fp52fzE226KSFUvRez {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-btq7fp52fzE226KSFUvRez {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-btq7fp52fzE226KSFUvRez {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-btq7fp52fzE226KSFUvRez span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-btq7fp52fzE226KSFUvRez span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-btq7fp52fzE226KSFUvRez img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-btq7fp52fzE226KSFUvRez span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-btq7fp52fzE226KSFUvRez span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-btq7fp52fzE226KSFUvRez]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-btq7fp52fzE226KSFUvRez]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-btq7fp52fzE226KSFUvRez]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-btq7fp52fzE226KSFUvRez">
#     <div class="ipyplot-placeholder-div-btq7fp52fzE226KSFUvRez">
#         <div id="ipyplot-content-div-btq7fp52fzE226KSFUvRez-H4sr5Hi3m7F2R7zemdupQm" class="ipyplot-content-div-btq7fp52fzE226KSFUvRez">
#             <h4 style="font-size: 12px; word-wrap: break-word;">NIAIFO1LOOFBLWH</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://storage.googleapis.com/image-bucket-cc/product-images/8adc94e1-7b67-469f-8d33-4c8c9a63d7d2</h4><img src="https://storage.googleapis.com/image-bucket-cc/product-images/8adc94e1-7b67-469f-8d33-4c8c9a63d7d2"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-btq7fp52fzE226KSFUvRez-H4sr5Hi3m7F2R7zemdupQm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-btq7fp52fzE226KSFUvRez">
#         <div id="ipyplot-content-div-btq7fp52fzE226KSFUvRez-cnKKL8ySzBiQ3wP2CECBAF" class="ipyplot-content-div-btq7fp52fzE226KSFUvRez">
#             <h4 style="font-size: 12px; word-wrap: break-word;">OFXAIPRBL</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://storage.googleapis.com/image-bucket-cc/product-images/fcc7ed2b-4a8c-4858-8d11-eca2600324d4</h4><img src="https://storage.googleapis.com/image-bucket-cc/product-images/fcc7ed2b-4a8c-4858-8d11-eca2600324d4"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-btq7fp52fzE226KSFUvRez-cnKKL8ySzBiQ3wP2CECBAF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-btq7fp52fzE226KSFUvRez">
#         <div id="ipyplot-content-div-btq7fp52fzE226KSFUvRez-h8DDnpoHWUr95KHTnB4DMB" class="ipyplot-content-div-btq7fp52fzE226KSFUvRez">
#             <h4 style="font-size: 12px; word-wrap: break-word;">SAXBLLOWHPA</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://storage.googleapis.com/image-bucket-cc/product-images/e37d29d8-d6fd-45de-b180-6ac9111ea0d5</h4><img src="https://storage.googleapis.com/image-bucket-cc/product-images/e37d29d8-d6fd-45de-b180-6ac9111ea0d5"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-btq7fp52fzE226KSFUvRez-h8DDnpoHWUr95KHTnB4DMB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-btq7fp52fzE226KSFUvRez">
#         <div id="ipyplot-content-div-btq7fp52fzE226KSFUvRez-nXhmL8aa8BTn2P6AVzSBTc" class="ipyplot-content-div-btq7fp52fzE226KSFUvRez">
#             <h4 style="font-size: 12px; word-wrap: break-word;">AIMA90IN</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://storage.googleapis.com/image-bucket-cc/product-images/b24af22c-d90e-4d0f-8556-e3cf2f936265</h4><img src="https://storage.googleapis.com/image-bucket-cc/product-images/b24af22c-d90e-4d0f-8556-e3cf2f936265"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-btq7fp52fzE226KSFUvRez-nXhmL8aa8BTn2P6AVzSBTc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-btq7fp52fzE226KSFUvRez">
#         <div id="ipyplot-content-div-btq7fp52fzE226KSFUvRez-ZHTALQ48owomXbyVrX5htK" class="ipyplot-content-div-btq7fp52fzE226KSFUvRez">
#             <h4 style="font-size: 12px; word-wrap: break-word;">LOVUXNIAIFO1BYVIAB‘R</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://storage.googleapis.com/image-bucket-cc/product-images/710f28da-bf68-47bd-a3b5-43616470e7e7</h4><img src="https://storage.googleapis.com/image-bucket-cc/product-images/710f28da-bf68-47bd-a3b5-43616470e7e7"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-btq7fp52fzE226KSFUvRez-ZHTALQ48owomXbyVrX5htK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
